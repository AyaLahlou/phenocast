# %%
# !pip install xarray==0.21.1
# Out:
# Requirement already satisfied: xarray in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (0.21.1)
# Collecting xarray
#   Downloading xarray-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting zarr
#   Downloading zarr-2.18.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dask in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (2024.11.2)
# Requirement already satisfied: fsspec in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (2024.10.0)
# Requirement already satisfied: numpy>=1.24 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from xarray) (2.0.2)
# Requirement already satisfied: packaging>=23.1 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from xarray) (24.1)
# Requirement already satisfied: pandas>=2.1 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from xarray) (2.2.3)
# Collecting asciitree (from zarr)
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numcodecs>=0.10.0 (from zarr)
#   Downloading numcodecs-0.14.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.0 kB)
# Collecting fasteners (from zarr)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: click>=8.1 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (3.1.0)
# Requirement already satisfied: partd>=1.4.0 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from pandas>=2.1->xarray) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from pandas>=2.1->xarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from pandas>=2.1->xarray) (2024.2)
# Requirement already satisfied: locket in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from partd>=1.4.0->dask) (1.0.0)
# Requirement already satisfied: six>=1.5 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray) (1.16.0)
# Downloading xarray-2024.10.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.8 MB/s eta 0:00:00
# Downloading zarr-2.18.3-py3-none-any.whl (210 kB)
# Downloading numcodecs-0.14.0-cp311-cp311-macosx_10_9_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 25.9 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5033 sha256=9a52e8c84436f2a02151395980e3bf4d984dab5e2e22c6e4e8ec9bdfd0920b9f
#   Stored in directory: /Users/ayalahlou/Library/Caches/pip/wheels/71/c1/da/23077eb3b87d24d6f3852ed1ed1a1ac2d3c885ad6ebd2b4a07
# Successfully built asciitree
# Installing collected packages: asciitree, numcodecs, fasteners, zarr, xarray
#   Attempting uninstall: xarray
#     Found existing installation: xarray 0.21.1
#     Uninstalling xarray-0.21.1:
#       Successfully uninstalled xarray-0.21.1
# Successfully installed asciitree-0.3.3 fasteners-0.19 numcodecs-0.14.0 xarray-2024.10.0 zarr-2.18.3

# %%
# !pip install dask
# Out:
# Collecting dask
#   Downloading dask-2024.11.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting click>=8.1 (from dask)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle>=3.0.0 (from dask)
#   Downloading cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting fsspec>=2021.09.0 (from dask)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (24.1)
# Collecting partd>=1.4.0 (from dask)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from dask)
#   Downloading PyYAML-6.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting toolz>=0.10.0 (from dask)
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from dask) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /Users/ayalahlou/opt/anaconda3/envs/regrid_env/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask) (3.21.0)
# Collecting locket (from partd>=1.4.0->dask)
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading dask-2024.11.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.0 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-macosx_10_9_x86_64.whl (184 kB)
# Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: toolz, pyyaml, locket, fsspec, cloudpickle, click, partd, dask
# Successfully installed click-8.1.7 cloudpickle-3.1.0 dask-2024.11.2 fsspec-2024.10.0 locket-1.0.0 partd-1.4.2 pyyaml-6.0.2 toolz-1.0.0

# %%
import argparse
import os
from netCDF4 import Dataset
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import xesmf as xe
import dask
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
def get_csif(year,lat_s, lat_e, lon_s, lon_e, pft_path, pft_code):
    """
    Retrieve and process CSIF (Chlorophyll Fluorescence) data for a specified year and geographical region, 
    and apply a mask based on Plant Functional Type (PFT).
    
    Parameters:
        year (int): The year for which to retrieve the CSIF data.
        lat_s (float): The starting latitude of the region of interest.
        lat_e (float): The ending latitude of the region of interest.
        lon_s (float): The starting longitude of the region of interest.
        lon_e (float): The ending longitude of the region of interest.
        pft_path (str): The file path to the PFT map.
        pft_code (str): The code representing the Plant Functional Type of interest.
    
    Returns:
        xarray.Dataset: The processed CSIF data with the applied PFT mask and interpolated time series.
    """
    
    
    pft_dictionnary = {
    "TrBE": 1, #Tropical Broadleaf Evergreen # 
    "TrBD": 2, #Tropical Broadleaf Deciduous #
    "TeBE": 3, #Temperate Broadleaf Evergreen #
    "TeNE": 4, #Temperate Needleleaf Evergreen #
    "TeBD": 5, #Temperate Broadleaf Deciduous #
    "BoNE": 6, #Boreal Needleleaf Evergreen #
    "BoND": 7, #Boreal Needleleaf Deciduous #
    "Sav": 8, #Savanna #
    "Gra": 9, #Grassland #
    "Sch": 10, #Schrub #
    "Tun": 11, #Tundra #
    "Des": 12, #Desert
    "Ice": 13, #Polar-Desert_or_Rock_or_Ice 
    "Wat": 14, #Water
    "Cro": 15, #Cropland
    "Pas": 16, #Pastureland 
    "Urb": 17, #Urban 
    }

    desired_lat_values = np.linspace(90.0, -89.75, 720)
    desired_lon_values = np.arange(-180.0, 180, 0.25)

    csif_path='/Users/ayalahlou/Desktop/All Data/csif_biweekly_lowres/'+str(year)+'_csif_24x720x1440.nc'
    csif = xr.open_dataset(csif_path)
    csif['latitude']=desired_lat_values
    csif['longitude']=desired_lon_values

    csif = csif.sel(latitude=slice(lat_e, lat_s))
    csif = csif.sel(longitude=slice(lon_s, lon_e))


    #for jan1st to Jan15th
    if year>1982:
        csif_path_2='/Users/ayalahlou/Desktop/All Data/csif_biweekly_lowres/'+str(year-1)+'_csif_24x720x1440.nc'
        csif_2 = xr.open_dataset(csif_path_2)
        csif_2['latitude']=desired_lat_values
        csif_2['longitude']=desired_lon_values
        #slice according to the area of interest
        csif_2 = csif_2.sel(latitude=slice(lat_e, lat_s))
        csif_2 = csif_2.sel(longitude=slice(lon_s, lon_e))
        csif_2 = csif_2.sel(time=slice(str(year-1)+'-12-30', str(year)+'-01-01'))
        ds = xr.merge([csif_2, csif], join='outer') 
    elif year==1982:
        ds=csif

    sif_inst= ds['sif_clear_inst'].values


    sif_inst=sif_inst.reshape(len(ds['time']),len(csif['latitude']), len(csif['longitude']))

    #flip upside down each netcdf for each month
    #for i in range(len(ds['time'])):
        #sif_inst[i]=np.flipud(sif_inst[i])

    ds= ds.drop_vars(["sif_clear_daily"])

    #OPEN binary pft map
    pft_path = pft_path
    pft = xr.open_dataset(pft_path)
    pft = pft.sel(latitude=slice(lat_e, lat_s))
    pft = pft.sel(longitude=slice(lon_s, lon_e))
    arr_pft= pft['Dominant_type'].values           #define PFT of interest 
    #arr_pft[0]=np.flipud(arr_pft[0])
    
    #apply mask to csif data
    mask = (arr_pft[0] != pft_dictionnary[pft_code]) #mask of everything but pft of interest
    sif_inst[:, mask] = np.nan # Apply the mask to sif_inst for all 24 slices


    start_date = pd.to_datetime(ds['time'].min().values)
    end_date = pd.to_datetime(ds['time'].max().values)
    new_time_array = pd.date_range(start=start_date, end=end_date, freq='D')

    ds_interpolated = ds.interp(time=new_time_array, method='linear')
    ds_interpolated['sif_clear_inst'] = ds_interpolated['sif_clear_inst'].rolling(time=10, min_periods=1, center=True).mean()

    if year>1982:
        ds_interpolated=ds_interpolated.isel(time=slice(1,None))
        
    return ds_interpolated


def get_era5(year, lat_s, lat_e, lon_s, lon_e, precp_path,  max_temp_path, min_temp_path,rad_path, sm_path):
    """
    Retrieve and combine ERA5 climate data for a specified year and geographical region.
    Parameters:
    year (int): The year for which to retrieve the data.
    lat_s (float): The starting latitude of the region.
    lat_e (float): The ending latitude of the region.
    lon_s (float): The starting longitude of the region.
    lon_e (float): The ending longitude of the region.
    precp_path (str): The file path to the precipitation data directory.
    max_temp_path (str): The file path to the maximum temperature data directory.
    min_temp_path (str): The file path to the minimum temperature data directory.
    rad_path (str): The file path to the radiation data directory.
    sm_path (str): The file path to the soil moisture data directory.
    Returns:
    xarray.Dataset: A combined dataset containing minimum temperature, maximum temperature, radiation, precipitation, and soil moisture data for the specified year and region.
    """
    

    #_________________________________________RADIATION___________________________________
    print('getting radiation for', str(year))                                                                       
    year_folder_path = os.path.join(rad_path, str(year))                                                                         
    ds_rad = read_netcdf_file(year_folder_path, lat_s, lat_e, lon_s, lon_e,)

    #_________________________________________PRECIPITATION_________________________________________
    print('getting precipitation for', str(year))                                                                       
    year_folder_path = os.path.join(precp_path, str(year))                                                                         
    ds_precp = read_netcdf_file(year_folder_path, lat_s, lat_e, lon_s, lon_e,)

    #_________________________________________MAX_TEMP________________________________________
    print('getting max temp for', str(year))                                                                       
    year_folder_path = os.path.join(max_temp_path, str(year))                                                                         
    ds_max_temp = read_netcdf_file(year_folder_path, lat_s, lat_e, lon_s, lon_e,)

    #_________________________________________MIN_TEMP________________________________________
    print('getting min temp for', str(year))                                                                       
    year_folder_path = os.path.join(min_temp_path, str(year))                                                                         
    ds_min_temp = read_netcdf_file(year_folder_path, lat_s, lat_e, lon_s, lon_e,)
    
    #_________________________________________SM________________________________________
    print('getting soil moisture for', str(year))                                                                       
    year_folder_path = sm_path+"/era5_SM_layer1_"+str(year)+".nc"                                                                         
    ds_sm = read_netcdf_file(year_folder_path, lat_s, lat_e, lon_s, lon_e, True)
    
    combined_ds = xr.merge([ds_min_temp, ds_max_temp, ds_rad, ds_precp, ds_sm])
    combined_ds = combined_ds.rename({'time': 'time', 'lat': 'latitude', 'lon': 'longitude','air_temperature_at_2_metres_1hour_Minimum': 'tmin', 'air_temperature_at_2_metres_1hour_Maximum': 'tmax', 'integral_wrt_time_of_surface_direct_downwelling_shortwave_flux_in_air_1hour_Accumulation': 'radiation', 'precipitation_amount_1hour_Accumulation':'precipitation' ,"swvl1":"sm" })
    return combined_ds

def get_1982_ref(lat_s, lat_e, lon_s, lon_e, pft_path, precp_path,  max_temp_path, min_temp_path,rad_path, sm_path, pft_code):
    """
    Retrieve and combine CSIF and ERA5 datasets for the year 1982 within specified latitude and longitude bounds.
    Parameters:
    lat_s (float): Starting latitude.
    lat_e (float): Ending latitude.
    lon_s (float): Starting longitude.
    lon_e (float): Ending longitude.
    pft_path (str): File path to the PFT (Plant Functional Type) data.
    precp_path (str): File path to the precipitation data.
    max_temp_path (str): File path to the maximum temperature data.
    min_temp_path (str): File path to the minimum temperature data.
    rad_path (str): File path to the radiation data.
    sm_path (str): File path to the soil moisture data.
    pft_code (int): PFT code to filter the data.
    Returns:
    xarray.Dataset: Combined dataset containing CSIF and ERA5 data for the year 1982.
    """
    
    year=1982
    csif_ds= get_csif(year,lat_s, lat_e, lon_s, lon_e, pft_path, pft_code)
    era5_ds= get_era5(year,lat_s, lat_e, lon_s, lon_e, precp_path,  max_temp_path, min_temp_path,rad_path, sm_path)
    # We don't have CSIF data for before 1982-01-15 so we truncate the era5 data for compatibility
    era5_ds = era5_ds.sel(time=slice('1982-01-15',None))
    combined_ds = xr.merge([csif_ds, era5_ds])
    return combined_ds

def read_netcdf_file(filepath,lat_s, lat_e, lon_s, lon_e, SM=False):
    """
    Read a netCDF file and extract data within specified latitude and longitude bounds.
    Parameters:
    filepath (str): File path to the netCDF file.
    lat_s (float): Starting latitude.
    lat_e (float): Ending latitude.
    lon_s (float): Starting longitude.
    lon_e (float): Ending longitude.
    SM (bool): Whether the data is soil moisture data.
    Returns:
    xarray.Dataset: Dataset containing the extracted data.
    """
    if SM:
        ds = xr.open_dataset(filepath)
        ds['longitude'] = (ds['longitude'] + 180) % 360 - 180
        ds = xr.concat([ds.sel(longitude=slice(-180, -0.25)), ds.sel(longitude=slice(0, 179.75))], dim="longitude") #center around africa
        ds = ds.sel(latitude=slice(lat_e, lat_s))
        ds = ds.sel(longitude=slice(lon_s, lon_e))
        ds=ds.rename({'latitude':'lat', 'longitude':'lon'})
    else:
        ds = xr.open_mfdataset(filepath+'/*.nc')
        ds['lon'] = (ds['lon'] + 180) % 360 - 180
        ds = xr.concat([ds.sel(lon=slice(-180, -0.25)), ds.sel(lon=slice(0, 179.75))], dim="lon") #center around africa
        ds = ds.sel(lat=slice(lat_e, lat_s))
        ds = ds.sel(lon=slice(lon_s, lon_e))
        ds=ds.rename({'time1':'time'})

    return ds

def process_one_year(year,lat_s, lat_e, lon_s, lon_e, pft_path, precp_path,  max_temp_path, min_temp_path,rad_path, sm_path, ref_1982, pft_code, output_path):
    """
    Process and save data for a single year.
    Parameters:
    year (int): The year to process.
    lat_s (float): The starting latitude of the region of interest.
    lat_e (float): The ending latitude of the region of interest.
    lon_s (float): The starting longitude of the region of interest.
    lon_e (float): The ending longitude of the region of interest.
    pft_path (str): The file path to the PFT map.
    precp_path (str): The file path to the precipitation data.
    max_temp_path (str): The file path to the maximum temperature data.
    min_temp_path (str): The file path to the minimum temperature data.
    rad_path (str): The file path to the radiation data.
    sm_path (str): The file path to the soil moisture data.
    ref_1982 (xarray.Dataset): The reference dataset for the year 1982.
    pft_code (str): The code representing the Plant Functional Type of interest.
    output_path (str): The output directory to save the processed data.
    """
    if year==1982:
        concatenated = ref_1982.stack(location=('latitude', 'longitude'))
        concatenated = concatenated.dropna(dim='location', how='all', subset=['sif_clear_inst'] )
        concatenated = concatenated.reset_index('location')
        concatenated['sif_clear_inst'] = concatenated['sif_clear_inst'].interpolate_na(dim='time', method="cubic", fill_value="extrapolate")
        print('year '+str(year)+' before dropping for any nan'+str( len(concatenated['location'])))
        concatenated = concatenated.dropna(dim='location', how='any', subset=['sif_clear_inst'] )
        result_ds = concatenated.to_dataframe().reset_index()
        print(year, len(result_ds['location']), len(result_ds['time']))
        result_ds.to_parquet(output_path+'/full_'+str(year)+'_daily_NoNAN.parquet', compression='snappy', engine='pyarrow')
    else:
        #get csif for current year 
        csif_ds= get_csif(year,lat_s, lat_e, lon_s, lon_e, pft_path, pft_code)
        #get era 5 for current year
        era5_ds= get_era5(year,lat_s, lat_e, lon_s, lon_e, precp_path,  max_temp_path, min_temp_path,rad_path, sm_path)
        #merge 
        combined_ds = xr.merge([csif_ds, era5_ds])
        #concatenate xarray dataset with 1982 dataset 
        concatenated = xr.concat([ref_1982,combined_ds], dim='time')
        #stack 
        concatenated = concatenated.stack(location=('latitude', 'longitude'))
        #remove na 
        concatenated = concatenated.dropna(dim='location', how='all', subset=['sif_clear_inst'] )
        if year>=2001:
            current_year = concatenated.sel(time=slice(str(year)+'-01-01',None))#['sif_clear_inst'] = concatenated.sel(time=slice(None,str(year)+'-01-01'))['sif_clear_inst'].interpolate_na(dim='time', method="cubic", fill_value="extrapolate", max_gap='60D')
            current_year['sif_clear_inst'] = current_year['sif_clear_inst'].interpolate_na(dim='time', method="cubic", fill_value="extrapolate")
            current_year = current_year.fillna(0)
            again_together = xr.concat([concatenated.sel(time=slice(None, '1982-12-31')),current_year], dim='time')
            concatenated = again_together.dropna(dim='location', thresh=367, subset=['sif_clear_inst'])
        concatenated = concatenated.reset_index('location')
        concatenated['sif_clear_inst'] = concatenated['sif_clear_inst'].interpolate_na(dim='time', method="cubic", fill_value="extrapolate")
        print('year '+str(year)+' before dropping for any nan'+str( len(concatenated['location'])))
        concatenated = concatenated.dropna(dim='location', how='any', subset=['sif_clear_inst'] )
        #remove 1982 data 
        result_ds=concatenated.sel(time=slice(str(year)+'-01-01',None))
        print(year, len(result_ds['location']), len(result_ds['time']))
        #save 
        result_ds = result_ds.to_dataframe().reset_index()
        result_ds.to_parquet(output_path+'full_'+str(year)+'_daily_NoNAN.parquet', compression='snappy', engine='pyarrow')
        
        
def plot_map(ds_variable,title=None):
    """
    Plot a map of a variable in an xarray dataset.
    Parameters:
    ds_variable (xarray.DataArray): The variable to plot.
    title (str): The title of the plot.
    """

    for i in range(24):
        ds_variable[i]=np.flipud(ds_variable[i])
    
    # Assuming sif_inst has shape (24, 141, 1440)
    # Select a specific time slice to plot, e.g., the first time slice
    time_slice = 0
    data_to_plot = ds_variable[time_slice]
    # Assuming you have latitude and longitude arrays
    # Replace these with your actual latitude and longitude arrays
    lat = np.linspace(30, 75, data_to_plot.shape[0])
    lon = np.linspace(-180, 180, data_to_plot.shape[1])

    # Create a figure and axis with a map projection
    fig, ax = plt.subplots(figsize=(15, 4), subplot_kw={'projection': ccrs.PlateCarree()})

    # Plot the data
    c = ax.pcolormesh(lon, lat, data_to_plot, transform=ccrs.PlateCarree(), cmap='viridis')

    # Add coastlines and other features
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAND, edgecolor='black')
    ax.add_feature(cfeature.OCEAN)


    # Add a colorbar
    fig.colorbar(c, ax=ax, orientation='vertical', label='SIF')

    # Set the title
    ax.set_title(title)

    # Show the plot
    plt.show()

# %%
year=2001

lat_e=75
lat_s=30
lon_s=-180
lon_e=180

pft_code= 'BoNE' #climate_leaftype_seasonality
csif_path='/Users/ayalahlou/Desktop/All Data/csif_biweekly_lowres/'+str(year)+'_csif_24x720x1440.nc'
pft_path = "/Users/ayalahlou/Downloads/regridded_landcover-HYDEAREAVEG-fc_Historical_Land-Cover_Change_and_Land-Use_Conversions_Global_Dataset__HYDE_AREAVEG_Feature_Collection_best.nc"#2011
precp_path='/Users/ayalahlou/Desktop/All Data/era5_daily/precip'
max_temp_path='/Users/ayalahlou/Desktop/All Data/era5_daily/max_temp'
min_temp_path='/Users/ayalahlou/Desktop/All Data/era5_daily/min_temp'
rad_path='/Users/ayalahlou/Desktop/All Data/era5_daily/radiation'
sm_path= "/Users/ayalahlou/Desktop/All Data/scripts/soilmoisture"

output_path='/Users/ayalahlou/Desktop/All Data/Boreal_Clustering/'+pft_code+"/"

# %%
ref_1982= get_1982_ref(lat_s, lat_e, lon_s, lon_e, pft_path, precp_path,  max_temp_path, min_temp_path,rad_path, sm_path, pft_code)
for year in range(1982,2022):
    process_one_year(year,lat_s, lat_e, lon_s, lon_e, pft_path, precp_path,  max_temp_path, min_temp_path, rad_path, sm_path, ref_1982, pft_code, output_path)
# Out:
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan11502
# 1982 4037202 4037202
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan11502
# 1983 11502 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan11502
# 1984 11502 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan11502
# 1985 11502 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan11502
# 1986 11502 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan11502
# 1987 11502 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan11502
# 1988 11502 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan11502
# 1989 11502 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan11502
# 1990 11502 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan11502
# 1991 11502 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan11502
# 1992 11502 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan11502
# 1993 11502 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan11502
# 1994 11502 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan11502
# 1995 11502 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan11502
# 1996 11502 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan11502
# 1997 11502 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan11502
# 1998 11502 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan11502
# 1999 11502 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan11502
# 2000 11502 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan11502
# 2001 11502 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan11502
# 2002 11502 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan11502
# 2003 11502 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan11502
# 2004 11502 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan11502
# 2005 11502 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan11502
# 2006 11502 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan11502
# 2007 11502 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan11502
# 2008 11502 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan11502
# 2009 11502 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan11502
# 2010 11502 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan11502
# 2011 11502 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan11502
# 2012 11502 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan11502
# 2013 11502 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan11502
# 2014 11502 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan11502
# 2015 11502 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan11502
# 2016 11502 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan11502
# 2017 11502 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan11502
# 2018 11502 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan11502
# 2019 11502 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan11502
# 2020 11502 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan11502
# 2021 11502 365

# %%
csif_path='/Users/ayalahlou/Desktop/All Data/csif_biweekly_lowres/'+str(year)+'_csif_24x720x1440.nc'
pft_path = "/Users/ayalahlou/Downloads/regridded_landcover-HYDEAREAVEG-fc_Historical_Land-Cover_Change_and_Land-Use_Conversions_Global_Dataset__HYDE_AREAVEG_Feature_Collection_best.nc"#2011
precp_path='/Users/ayalahlou/Desktop/All Data/era5_daily/precip'
max_temp_path='/Users/ayalahlou/Desktop/All Data/era5_daily/max_temp'
min_temp_path='/Users/ayalahlou/Desktop/All Data/era5_daily/min_temp'
rad_path='/Users/ayalahlou/Desktop/All Data/era5_daily/radiation'
sm_path= "/Users/ayalahlou/Desktop/All Data/scripts/soilmoisture"

# 
lat_e=70
lat_s=-60
lon_s=-240
lon_e=180

selected_pfts=['TrBE', 'TrBD', 'TeBE', 'TeNE', 'TeBD', 'BoND', 'Sav', 'Gra', 'Sch', 'Tun']
for pft_code in selected_pfts:
    if pft_code=="Tun":
        lat_e=90
        lat_s=60
        lon_s=-180
        lon_e=180
        
    #make output directory
    output_path='/Users/ayalahlou/Desktop/All Data/Boreal_Clustering/'+pft_code+"/"
    if not os.path.exists(output_path):
        os.makedirs(output_path)
        
    print('__________processing______________', pft_code)
    ref_1982= get_1982_ref(lat_s, lat_e, lon_s, lon_e, pft_path, precp_path,  max_temp_path, min_temp_path,rad_path, sm_path, pft_code)
    for year in range(1982,2022):
        process_one_year(year,lat_s, lat_e, lon_s, lon_e, pft_path, precp_path,  max_temp_path, min_temp_path, rad_path, sm_path, ref_1982, pft_code, output_path)
# Out:
# __________processing______________ TrBE
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan13674
# 1982 4799574 4799574
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan13674
# 1983 13674 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan13674
# 1984 13674 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan13674
# 1985 13674 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan13674
# 1986 13674 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan13674
# 1987 13674 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan13674
# 1988 13674 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan13674
# 1989 13674 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan13674
# 1990 13674 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan13674
# 1991 13674 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan13674
# 1992 13674 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan13674
# 1993 13674 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan13674
# 1994 13674 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan13674
# 1995 13674 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan13674
# 1996 13674 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan13674
# 1997 13674 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan13674
# 1998 13674 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan13674
# 1999 13674 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan13674
# 2000 13674 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan13674
# 2001 13674 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan13674
# 2002 13674 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan13674
# 2003 13674 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan13674
# 2004 13674 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan13674
# 2005 13674 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan13674
# 2006 13674 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan13674
# 2007 13674 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan13674
# 2008 13674 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan13674
# 2009 13674 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan13674
# 2010 13674 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan13674
# 2011 13674 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan13674
# 2012 13674 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan13674
# 2013 13674 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan13674
# 2014 13674 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan13674
# 2015 13674 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan13674
# 2016 13674 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan13674
# 2017 13674 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan13674
# 2018 13674 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan13674
# 2019 13674 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan13674
# 2020 13674 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan13674
# 2021 13674 365
# __________processing______________ TrBD
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan156
# 1982 54756 54756
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan156
# 1983 156 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan156
# 1984 156 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan156
# 1985 156 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan156
# 1986 156 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan156
# 1987 156 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan156
# 1988 156 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan156
# 1989 156 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan156
# 1990 156 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan156
# 1991 156 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan156
# 1992 156 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan156
# 1993 156 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan156
# 1994 156 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan156
# 1995 156 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan156
# 1996 156 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan156
# 1997 156 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan156
# 1998 156 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan156
# 1999 156 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan156
# 2000 156 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan156
# 2001 156 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan156
# 2002 156 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan156
# 2003 156 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan156
# 2004 156 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan156
# 2005 156 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan156
# 2006 156 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan156
# 2007 156 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan156
# 2008 156 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan156
# 2009 156 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan156
# 2010 156 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan156
# 2011 156 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan156
# 2012 156 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan156
# 2013 156 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan156
# 2014 156 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan156
# 2015 156 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan156
# 2016 156 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan156
# 2017 156 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan156
# 2018 156 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan156
# 2019 156 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan156
# 2020 156 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan156
# 2021 156 365
# __________processing______________ TeBE
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan218
# 1982 76518 76518
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan218
# 1983 218 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan218
# 1984 218 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan218
# 1985 218 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan218
# 1986 218 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan218
# 1987 218 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan218
# 1988 218 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan218
# 1989 218 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan218
# 1990 218 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan218
# 1991 218 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan218
# 1992 218 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan218
# 1993 218 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan218
# 1994 218 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan218
# 1995 218 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan218
# 1996 218 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan218
# 1997 218 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan218
# 1998 218 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan218
# 1999 218 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan218
# 2000 218 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan218
# 2001 218 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan218
# 2002 218 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan218
# 2003 218 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan218
# 2004 218 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan218
# 2005 218 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan218
# 2006 218 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan218
# 2007 218 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan218
# 2008 218 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan218
# 2009 218 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan218
# 2010 218 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan218
# 2011 218 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan218
# 2012 218 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan218
# 2013 218 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan218
# 2014 218 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan218
# 2015 218 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan218
# 2016 218 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan218
# 2017 218 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan218
# 2018 218 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan218
# 2019 218 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan218
# 2020 218 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan218
# 2021 218 365
# __________processing______________ TeNE
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan3036
# 1982 1065636 1065636
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan3036
# 1983 3036 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan3036
# 1984 3036 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan3036
# 1985 3036 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan3036
# 1986 3036 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan3036
# 1987 3036 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan3036
# 1988 3036 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan3036
# 1989 3036 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan3036
# 1990 3036 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan3036
# 1991 3036 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan3036
# 1992 3036 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan3036
# 1993 3036 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan3036
# 1994 3036 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan3036
# 1995 3036 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan3036
# 1996 3036 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan3036
# 1997 3036 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan3036
# 1998 3036 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan3036
# 1999 3036 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan3036
# 2000 3036 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan3036
# 2001 3036 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan3036
# 2002 3036 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan3036
# 2003 3036 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan3036
# 2004 3036 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan3036
# 2005 3036 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan3036
# 2006 3036 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan3036
# 2007 3036 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan3036
# 2008 3036 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan3036
# 2009 3036 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan3036
# 2010 3036 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan3036
# 2011 3036 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan3036
# 2012 3036 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan3036
# 2013 3036 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan3036
# 2014 3036 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan3036
# 2015 3036 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan3036
# 2016 3036 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan3036
# 2017 3036 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan3036
# 2018 3036 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan3036
# 2019 3036 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan3036
# 2020 3036 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan3036
# 2021 3036 365
# __________processing______________ TeBD
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan2088
# 1982 732888 732888
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan2088
# 1983 2088 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan2088
# 1984 2088 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan2088
# 1985 2088 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan2088
# 1986 2088 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan2088
# 1987 2088 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan2088
# 1988 2088 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan2088
# 1989 2088 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan2088
# 1990 2088 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan2088
# 1991 2088 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan2088
# 1992 2088 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan2088
# 1993 2088 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan2088
# 1994 2088 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan2088
# 1995 2088 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan2088
# 1996 2088 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan2088
# 1997 2088 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan2088
# 1998 2088 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan2088
# 1999 2088 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan2088
# 2000 2088 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan2088
# 2001 2088 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan2088
# 2002 2088 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan2088
# 2003 2088 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan2088
# 2004 2088 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan2088
# 2005 2088 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan2088
# 2006 2088 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan2088
# 2007 2088 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan2088
# 2008 2088 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan2088
# 2009 2088 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan2088
# 2010 2088 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan2088
# 2011 2088 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan2088
# 2012 2088 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan2088
# 2013 2088 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan2088
# 2014 2088 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan2088
# 2015 2088 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan2088
# 2016 2088 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan2088
# 2017 2088 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan2088
# 2018 2088 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan2088
# 2019 2088 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan2088
# 2020 2088 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan2088
# 2021 2088 365
# __________processing______________ BoND
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan4804
# 1982 1686204 1686204
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan4804
# 1983 4804 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan4804
# 1984 4804 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan4804
# 1985 4804 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan4804
# 1986 4804 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan4804
# 1987 4804 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan4804
# 1988 4804 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan4804
# 1989 4804 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan4804
# 1990 4804 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan4804
# 1991 4804 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan4804
# 1992 4804 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan4804
# 1993 4804 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan4804
# 1994 4804 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan4804
# 1995 4804 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan4804
# 1996 4804 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan4804
# 1997 4804 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan4804
# 1998 4804 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan4804
# 1999 4804 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan4804
# 2000 4804 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan4804
# 2001 4804 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan4804
# 2002 4804 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan4804
# 2003 4804 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan4804
# 2004 4804 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan4804
# 2005 4804 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan4804
# 2006 4804 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan4804
# 2007 4804 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan4804
# 2008 4804 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan4804
# 2009 4804 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan4804
# 2010 4804 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan4804
# 2011 4804 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan4804
# 2012 4804 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan4804
# 2013 4804 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan4804
# 2014 4804 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan4804
# 2015 4804 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan4804
# 2016 4804 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan4804
# 2017 4804 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan4804
# 2018 4804 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan4804
# 2019 4804 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan4804
# 2020 4804 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan4804
# 2021 4804 365
# __________processing______________ Sav
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan3340
# 1982 1172340 1172340
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan3340
# 1983 3340 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# ...
# year 2021 before dropping for any nan11962
# 2021 11962 365
# __________processing______________ Sch
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan3564
# 1982 1250964 1250964
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan3564
# 1983 3564 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan3564
# 1984 3564 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan3564
# 1985 3564 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan3564
# 1986 3564 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan3564
# 1987 3564 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan3564
# 1988 3564 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan3564
# 1989 3564 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan3564
# 1990 3564 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan3564
# 1991 3564 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan3564
# 1992 3564 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan3564
# 1993 3564 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan3564
# 1994 3564 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan3564
# 1995 3564 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan3564
# 1996 3564 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan3564
# 1997 3564 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan3564
# 1998 3564 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan3564
# 1999 3564 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan3564
# 2000 3564 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan3564
# 2001 3564 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan3564
# 2002 3564 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan3564
# 2003 3564 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan3564
# 2004 3564 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan3564
# 2005 3564 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan3564
# 2006 3564 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan3564
# 2007 3564 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan3564
# 2008 3564 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan3564
# 2009 3564 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan3564
# 2010 3564 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan3564
# 2011 3564 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan3564
# 2012 3564 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan3564
# 2013 3564 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan3564
# 2014 3564 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan3564
# 2015 3564 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan3564
# 2016 3564 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan3564
# 2017 3564 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan3564
# 2018 3564 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan3564
# 2019 3564 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan3564
# 2020 3564 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan3564
# 2021 3564 365
# __________processing______________ Tun
# getting radiation for 1982
# getting precipitation for 1982
# getting max temp for 1982
# getting min temp for 1982
# getting soil moisture for 1982
# year 1982 before dropping for any nan18132
# 1982 6364332 6364332
# getting radiation for 1983
# getting precipitation for 1983
# getting max temp for 1983
# getting min temp for 1983
# getting soil moisture for 1983
# year 1983 before dropping for any nan18132
# 1983 18132 365
# getting radiation for 1984
# getting precipitation for 1984
# getting max temp for 1984
# getting min temp for 1984
# getting soil moisture for 1984
# year 1984 before dropping for any nan18132
# 1984 18132 366
# getting radiation for 1985
# getting precipitation for 1985
# getting max temp for 1985
# getting min temp for 1985
# getting soil moisture for 1985
# year 1985 before dropping for any nan18132
# 1985 18132 365
# getting radiation for 1986
# getting precipitation for 1986
# getting max temp for 1986
# getting min temp for 1986
# getting soil moisture for 1986
# year 1986 before dropping for any nan18132
# 1986 18132 365
# getting radiation for 1987
# getting precipitation for 1987
# getting max temp for 1987
# getting min temp for 1987
# getting soil moisture for 1987
# year 1987 before dropping for any nan18132
# 1987 18132 365
# getting radiation for 1988
# getting precipitation for 1988
# getting max temp for 1988
# getting min temp for 1988
# getting soil moisture for 1988
# year 1988 before dropping for any nan18132
# 1988 18132 366
# getting radiation for 1989
# getting precipitation for 1989
# getting max temp for 1989
# getting min temp for 1989
# getting soil moisture for 1989
# year 1989 before dropping for any nan18132
# 1989 18132 365
# getting radiation for 1990
# getting precipitation for 1990
# getting max temp for 1990
# getting min temp for 1990
# getting soil moisture for 1990
# year 1990 before dropping for any nan18132
# 1990 18132 365
# getting radiation for 1991
# getting precipitation for 1991
# getting max temp for 1991
# getting min temp for 1991
# getting soil moisture for 1991
# year 1991 before dropping for any nan18132
# 1991 18132 365
# getting radiation for 1992
# getting precipitation for 1992
# getting max temp for 1992
# getting min temp for 1992
# getting soil moisture for 1992
# year 1992 before dropping for any nan18132
# 1992 18132 366
# getting radiation for 1993
# getting precipitation for 1993
# getting max temp for 1993
# getting min temp for 1993
# getting soil moisture for 1993
# year 1993 before dropping for any nan18132
# 1993 18132 365
# getting radiation for 1994
# getting precipitation for 1994
# getting max temp for 1994
# getting min temp for 1994
# getting soil moisture for 1994
# year 1994 before dropping for any nan18132
# 1994 18132 365
# getting radiation for 1995
# getting precipitation for 1995
# getting max temp for 1995
# getting min temp for 1995
# getting soil moisture for 1995
# year 1995 before dropping for any nan18132
# 1995 18132 365
# getting radiation for 1996
# getting precipitation for 1996
# getting max temp for 1996
# getting min temp for 1996
# getting soil moisture for 1996
# year 1996 before dropping for any nan18132
# 1996 18132 366
# getting radiation for 1997
# getting precipitation for 1997
# getting max temp for 1997
# getting min temp for 1997
# getting soil moisture for 1997
# year 1997 before dropping for any nan18132
# 1997 18132 365
# getting radiation for 1998
# getting precipitation for 1998
# getting max temp for 1998
# getting min temp for 1998
# getting soil moisture for 1998
# year 1998 before dropping for any nan18132
# 1998 18132 365
# getting radiation for 1999
# getting precipitation for 1999
# getting max temp for 1999
# getting min temp for 1999
# getting soil moisture for 1999
# year 1999 before dropping for any nan18132
# 1999 18132 365
# getting radiation for 2000
# getting precipitation for 2000
# getting max temp for 2000
# getting min temp for 2000
# getting soil moisture for 2000
# year 2000 before dropping for any nan18132
# 2000 18132 366
# getting radiation for 2001
# getting precipitation for 2001
# getting max temp for 2001
# getting min temp for 2001
# getting soil moisture for 2001
# year 2001 before dropping for any nan18132
# 2001 18132 365
# getting radiation for 2002
# getting precipitation for 2002
# getting max temp for 2002
# getting min temp for 2002
# getting soil moisture for 2002
# year 2002 before dropping for any nan18132
# 2002 18132 365
# getting radiation for 2003
# getting precipitation for 2003
# getting max temp for 2003
# getting min temp for 2003
# getting soil moisture for 2003
# year 2003 before dropping for any nan18132
# 2003 18132 365
# getting radiation for 2004
# getting precipitation for 2004
# getting max temp for 2004
# getting min temp for 2004
# getting soil moisture for 2004
# year 2004 before dropping for any nan18132
# 2004 18132 366
# getting radiation for 2005
# getting precipitation for 2005
# getting max temp for 2005
# getting min temp for 2005
# getting soil moisture for 2005
# year 2005 before dropping for any nan18132
# 2005 18132 365
# getting radiation for 2006
# getting precipitation for 2006
# getting max temp for 2006
# getting min temp for 2006
# getting soil moisture for 2006
# year 2006 before dropping for any nan18132
# 2006 18132 365
# getting radiation for 2007
# getting precipitation for 2007
# getting max temp for 2007
# getting min temp for 2007
# getting soil moisture for 2007
# year 2007 before dropping for any nan18132
# 2007 18132 365
# getting radiation for 2008
# getting precipitation for 2008
# getting max temp for 2008
# getting min temp for 2008
# getting soil moisture for 2008
# year 2008 before dropping for any nan18132
# 2008 18132 366
# getting radiation for 2009
# getting precipitation for 2009
# getting max temp for 2009
# getting min temp for 2009
# getting soil moisture for 2009
# year 2009 before dropping for any nan18132
# 2009 18132 365
# getting radiation for 2010
# getting precipitation for 2010
# getting max temp for 2010
# getting min temp for 2010
# getting soil moisture for 2010
# year 2010 before dropping for any nan18132
# 2010 18132 365
# getting radiation for 2011
# getting precipitation for 2011
# getting max temp for 2011
# getting min temp for 2011
# getting soil moisture for 2011
# year 2011 before dropping for any nan18132
# 2011 18132 365
# getting radiation for 2012
# getting precipitation for 2012
# getting max temp for 2012
# getting min temp for 2012
# getting soil moisture for 2012
# year 2012 before dropping for any nan18132
# 2012 18132 366
# getting radiation for 2013
# getting precipitation for 2013
# getting max temp for 2013
# getting min temp for 2013
# getting soil moisture for 2013
# year 2013 before dropping for any nan18132
# 2013 18132 365
# getting radiation for 2014
# getting precipitation for 2014
# getting max temp for 2014
# getting min temp for 2014
# getting soil moisture for 2014
# year 2014 before dropping for any nan18132
# 2014 18132 365
# getting radiation for 2015
# getting precipitation for 2015
# getting max temp for 2015
# getting min temp for 2015
# getting soil moisture for 2015
# year 2015 before dropping for any nan18132
# 2015 18132 365
# getting radiation for 2016
# getting precipitation for 2016
# getting max temp for 2016
# getting min temp for 2016
# getting soil moisture for 2016
# year 2016 before dropping for any nan18132
# 2016 18132 366
# getting radiation for 2017
# getting precipitation for 2017
# getting max temp for 2017
# getting min temp for 2017
# getting soil moisture for 2017
# year 2017 before dropping for any nan18132
# 2017 18132 365
# getting radiation for 2018
# getting precipitation for 2018
# getting max temp for 2018
# getting min temp for 2018
# getting soil moisture for 2018
# year 2018 before dropping for any nan18132
# 2018 18132 365
# getting radiation for 2019
# getting precipitation for 2019
# getting max temp for 2019
# getting min temp for 2019
# getting soil moisture for 2019
# year 2019 before dropping for any nan18132
# 2019 18132 365
# getting radiation for 2020
# getting precipitation for 2020
# getting max temp for 2020
# getting min temp for 2020
# getting soil moisture for 2020
# year 2020 before dropping for any nan18132
# 2020 18132 366
# getting radiation for 2021
# getting precipitation for 2021
# getting max temp for 2021
# getting min temp for 2021
# getting soil moisture for 2021
# year 2021 before dropping for any nan18132
# 2021 18132 365
